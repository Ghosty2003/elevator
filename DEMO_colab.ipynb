# %%
# 1. 挂载 Drive
from google.colab import drive
drive.mount('/content/drive')

# 2. 设置路径
import os
lib_path = '/content/drive/MyDrive/colab_env/rm_dev'
os.makedirs(lib_path, exist_ok=True)

# 3. 安装最新兼容版本 (去掉版本号限制)
# 系统会自动选择最适合当前 Python 3.12+ 的 torch 和相关库
# !pip install --target=$lib_path \
    torch \
    torchvision \
    torchaudio \
    accelerate==0.33.0 \
    deepspeed==0.12.2 \
    transformers==4.43.4 \
    "numpy<2.0" \
    wandb
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ERROR: Could not find a version that satisfies the requirement torch==2.1.2 (from versions: 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1, 2.6.0, 2.7.0, 2.7.1, 2.8.0, 2.9.0, 2.9.1, 2.10.0)
# ERROR: No matching distribution found for torch==2.1.2

# %%
import sys
from google.colab import drive
drive.mount('/content/drive')

# 1. 将 Google Drive 的库路径添加到系统路径
lib_path = '/content/drive/MyDrive/colab_env/rm_dev'
if lib_path not in sys.path:
    sys.path.insert(0, lib_path)

# 2. 快速克隆代码库（如果没存的话）
# !git clone https://github.com/huggingface/alignment-handbook.git
# !git clone https://github.com/WeiXiongUST/RLHF-Reward-Modeling.git

# 3. 环境变量设置 (解决 CUDA_HOME 问题)
import os
os.environ['CUDA_HOME'] = '/usr/local/cuda'
os.environ['PATH'] += ':/usr/local/cuda/bin'

print("✅ 环境已恢复，可以开始训练！")
# Out:
# Mounted at /content/drive
# Cloning into 'alignment-handbook'...
# remote: Enumerating objects: 1386, done.
# remote: Counting objects: 100% (510/510), done.
# remote: Compressing objects: 100% (93/93), done.
# remote: Total 1386 (delta 459), reused 417 (delta 417), pack-reused 876 (from 1)
# Receiving objects: 100% (1386/1386), 333.71 KiB | 13.35 MiB/s, done.
# Resolving deltas: 100% (768/768), done.
# Cloning into 'RLHF-Reward-Modeling'...
# remote: Enumerating objects: 498, done.
# remote: Counting objects: 100% (216/216), done.
# remote: Compressing objects: 100% (110/110), done.
# remote: Total 498 (delta 170), reused 106 (delta 106), pack-reused 282 (from 2)
# Receiving objects: 100% (498/498), 3.93 MiB | 43.32 MiB/s, done.
# Resolving deltas: 100% (262/262), done.
# ✅ 环境已恢复，可以开始训练！

# %%
import wandb
import os


# 方案 B：使用 Colab Secrets（更安全，不会泄露 Key）
# 在 Colab 左侧侧边栏点击“钥匙”图标，添加名为 WANDB_API_KEY 的变量
from google.colab import userdata
os.environ["WANDB_API_KEY"] = userdata.get('WANDB_API_KEY')
wandb.login()

# %%
from huggingface_hub import login
from google.colab import userdata
login(userdata.get('HF_TOKEN'))
